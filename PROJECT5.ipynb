# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 

warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = sns.load_dataset('iris')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
X = df.drop('species',axis = 1)
y = df['species']

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# %%
base_learners = [
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('svc', SVC(probability = True, kernel='rbf', random_state = 42)),
    ('lr', LogisticRegression(max_iter=1000))
]

# %%
meta_learner = LogisticRegression(max_iter=1000)

# %%
stacking_clf = StackingClassifier(
    estimators = base_learners,
    final_estimator = meta_learner,
    cv=5
)

# %%
stacking_clf.fit(X_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                                ('svc', SVC(probability=True, random_state=42)),
#                                ('lr', LogisticRegression(max_iter=1000))],
#                    final_estimator=LogisticRegression(max_iter=1000))

# %%
y_pred = stacking_clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9666666666666667

# %% [markdown]
# # using knn as meta learner

# %%
from sklearn.neighbors import KNeighborsClassifier
meta_learner_knn = KNeighborsClassifier(n_neighbors = 5)

# %%
stacking_clf_knn = StackingClassifier(
    estimators = base_learners,
    final_estimator = meta_learner_knn,
    cv=5
)

# %%
stacking_clf_knn.fit(X_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                                ('svc', SVC(probability=True, random_state=42)),
#                                ('lr', LogisticRegression(max_iter=1000))],
#                    final_estimator=KNeighborsClassifier())

# %%
y_pred_knn = stacking_clf_knn.predict(X_test)

# %%
accuracy_knn = accuracy_score(y_test,y_pred)
accuracy_knn
# Out:
# 0.9666666666666667

# %% [markdown]
# # bagging (random forest)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(
    n_estimators=90,  # numbeer of tress
    max_depth = None,    # let tress grow fully
    random_state = 42
)

# %%
 model_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=90, random_state=42)

# %%
y_pred = model_rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.9333333333333333

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier

# %%
from xgboost import XGBClassifier

# %%
model_ada = AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
model_ada.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
y_pred_ada = model_ada.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred_ada)

# %%
accuracy
# Out:
# 0.9333333333333333

# %%
model_gb = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)

# %%
model_gb.fit(X_train,y_train)
y_pred_gb = model_gb.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred_gb)

# %%
accuracy
# Out:
# 0.9666666666666667

# %%
model_xgb = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, use_label_encoder=False, eval_metric='mlogloss', random_state=42)

# %%
model_xgb.fit(X_train,y_train)
y_pred_xgb = model_xgb.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred_xgb)

# %%
accuracy
# Out:
# 0.9333333333333333
